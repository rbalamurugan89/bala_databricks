# %% [markdown]
# # My first Databricks program..
# ## Happy Learning!!!
#
# ### Basic Notebook

# %%
# test
print("Hello Welcome..This is my first Databricks program..Happy Learning!!! ")

# %%
for i in range(10):
    print(i)

# %% [markdown]
# # All about Magic commands in Notebook

# %% [markdown]
# # Important magic commands
#
# - %md - allows to write markdown text , design your notebook
# - %python - switch python language in the code cell
# - %sql - switch code cell to sql code cell
# - %sh - allows to run shell commands , linux command
# - %fs - allows to intract with DBFS (databricks file system )
# - %scala - scala code
# - %pip - install python packages
# - %run -call another notebook or python
# - %r - allow to run  R language

# %% [markdown]
# ###  How to run sql in notebook using magic command

# %%
# %sql
--Not yet executed and seen

select current_datetime()

# %% [markdown]
# ### How to run Linux commands in Notebook using magic command

# %%
# %sh
pwd
ls -lrt

# %%
# %sh
touch abc.txt
echo 'Welcome' >> abc.txt

# %%
# %sh

cat abc.txt

# %% [markdown]
# ### Running another Notebook from this notebook using magic command %run

# %%
# %run "/Workspace/Users/rbalamurugan89@gmail.com/bala_databricks/SamplePythonNB"
